# %%
import pandas as pd

# %%
kaggle_hadiths_clean = pd.read_csv("kaggle_hadiths_clean.csv")
kaggle_hadiths_clean
# Out:
#         id  hadith_id             source  chapter_no hadith_no  \
# 0        0          1     Sahih Bukhari            1        1
# 1        1          2     Sahih Bukhari            1        2
# 2        2          3     Sahih Bukhari            1        3
# 3        3          4     Sahih Bukhari            1        4
# 4        4          5     Sahih Bukhari            1        5
# ...    ...        ...                ...         ...       ...
# 34436  173      54223   Sunan Ibn Majah           36     4234
# 34437  174      54224   Sunan Ibn Majah           36     4235
# 34438  175      54225   Sunan Ibn Majah           36     4236
# 34439  176      54226   Sunan Ibn Majah           36     4237
# 34440  177      54227   Sunan Ibn Majah           36     4238
#
#                            chapter                               chain_indx  \
# 0      Revelation - كتاب بدء الوحى     30418, 20005, 11062, 11213, 11042, 3
# ...

# %%
kaggle_rawis = pd.read_csv("kaggle_rawis.csv")
kaggle_rawis
# Out:
#        scholar_indx                                               name  \
# 0                 1  Prophet Muhammad(saw) ( محمّد صلّی اللہ علیہ و...
# 1                 2  Abu Bakr As-Siddique ( أبو بكر الصديق ( رضي ال...
# 2                 3  Umar ibn al-Khattab ( عمر بن الخطاب بن نفيل ( ...
# 3                 4  Uthman ibn 'Affaan ( عثمان بن عفان ( رضي الله عنه
# 4                 5  Ali ibn Abi Talib ( علي بن أبي طالب بن عبد الم...
# ...             ...                                                ...
# 24321         40019                        Muhammad Ishaq al-Kalabadhi
# 24322         40020                              Sulayman Ibn Muhammad
# 24323         40021                                         al-Khallal
# 24324         40022                                         al-Khiraqi
# 24325         40023                                  Ghulam al-Khallal
#
#                             grade  \
# 0                    Rasool Allah
# 1      Comp.(RA) [1st Generation]
# ...

# %%
kaggle_hadiths_clean.
